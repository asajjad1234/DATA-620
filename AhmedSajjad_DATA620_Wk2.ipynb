# %% [markdown]
# ## Data 620 - Week 2
# >### Ahmed Sajjad

# %%
Image(filename='Week2Assignment.png')

# %%
import networkx as nx
import matplotlib.pyplot as plt
from IPython.display import Image

adjacencyList = {"Andre"    : ["Beverly", "Carol", "Diane", "Fernando"],
                 "Beverly"  : ["Diane", "Ed", "Garth"],
                 "Carol"    : ["Diane", "Carol", "Fernando"],
                 "Diane"    : ["Ed", "Fernando", "Garth"],
                 "Ed"       : ["Garth"],
                 "Fernando" : ["Garth" , "Heather"],
                 "Garth"    : ["Heather"],
                 "Heather"  : ["Ike"],
                 "Ike"      : ["Jane"]}

# Graph object
graph = nx.Graph(adjacencyList)

# %%
nx.draw(graph, 
        node_color = '#01CCFF', 
        node_size = 1500, 
        node_shape = 'o', 
        with_labels = True)
plt.show()

# %%
graph_nodes = list(graph.nodes())
b = nx.betweenness_centrality(graph)
d = nx.degree_centrality(graph)
c = nx.closeness_centrality(graph)

print(graph_nodes)
for v in graph_nodes:
    print ("Degree(" + v + ")              = " + str(graph.degree(v)))
    print ("Betweenness(" + v + ")         = " + str(b[v]))
    print ("Degree Centrality(" + v + ")   = " + str(d[v]))
    print ("Closeness Centrality(" + v + ")= " + str(c[v]))
    print ("\n")
# Out:
# ['Andre', 'Beverly', 'Carol', 'Diane', 'Ed', 'Fernando', 'Garth', 'Heather', 'Ike', 'Jane']
# Degree(Andre)              = 4
# Betweenness(Andre)         = 0.023148148148148143
# Degree Centrality(Andre)   = 0.4444444444444444
# Closeness Centrality(Andre)= 0.5294117647058824
#
#
# Degree(Beverly)              = 4
# Betweenness(Beverly)         = 0.023148148148148143
# Degree Centrality(Beverly)   = 0.4444444444444444
# Closeness Centrality(Beverly)= 0.5294117647058824
#
#
# Degree(Carol)              = 5
# Betweenness(Carol)         = 0.0
# Degree Centrality(Carol)   = 0.5555555555555556
# Closeness Centrality(Carol)= 0.5
#
#
# Degree(Diane)              = 6
# Betweenness(Diane)         = 0.10185185185185183
# Degree Centrality(Diane)   = 0.6666666666666666
# Closeness Centrality(Diane)= 0.6
#
#
# Degree(Ed)              = 3
# Betweenness(Ed)         = 0.0
# Degree Centrality(Ed)   = 0.3333333333333333
# Closeness Centrality(Ed)= 0.5
#
#
# Degree(Fernando)              = 5
# Betweenness(Fernando)         = 0.23148148148148148
# Degree Centrality(Fernando)   = 0.5555555555555556
# Closeness Centrality(Fernando)= 0.6428571428571429
#
#
# Degree(Garth)              = 5
# Betweenness(Garth)         = 0.23148148148148148
# Degree Centrality(Garth)   = 0.5555555555555556
# Closeness Centrality(Garth)= 0.6428571428571429
#
#
# Degree(Heather)              = 3
# Betweenness(Heather)         = 0.38888888888888884
# Degree Centrality(Heather)   = 0.3333333333333333
# Closeness Centrality(Heather)= 0.6
#
#
# Degree(Ike)              = 2
# Betweenness(Ike)         = 0.2222222222222222
# Degree Centrality(Ike)   = 0.2222222222222222
# Closeness Centrality(Ike)= 0.42857142857142855
#
#
# Degree(Jane)              = 1
# Betweenness(Jane)         = 0.0
# Degree Centrality(Jane)   = 0.1111111111111111
# Closeness Centrality(Jane)= 0.3103448275862069

# %% [markdown]
# $^{1 :}$ __[NetworkX on Krackhardt Kite Social Network](https://networkx.github.io/documentation/networkx-1.10/reference/generated/networkx.generators.small.krackhardt_kite_graph.html)__
